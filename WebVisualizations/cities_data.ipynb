# %%
import pandas as pd
import numpy as np

# %%
file = 'cities.csv'
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
df.head()
# Out:
#    Unnamed: 0  Latitude  Longitude            City  Temperature  Humidity  \
# 0           0    -42.48     -73.76          Castro       284.15        62
# 1           1     54.02    -128.69         Kitimat       279.15        93
# 2           2     15.34      74.49           Vaini       293.27        97
# 3           3     -0.60      73.08       Hithadhoo       300.22        77
# 4           4     39.31     -74.98  Port Elizabeth       290.46        59
#
#    Cloudiness  Wind Speeds
# 0           0         3.10
# 1          90         4.10
# 2          99         0.05
# 3           6         4.80
# 4           1         3.52

# %%
cities_df = df.drop('Unnamed: 0', axis=1)
cities_df.head()
# Out:
#    Latitude  Longitude            City  Temperature  Humidity  Cloudiness  \
# 0    -42.48     -73.76          Castro       284.15        62           0
# 1     54.02    -128.69         Kitimat       279.15        93          90
# 2     15.34      74.49           Vaini       293.27        97          99
# 3     -0.60      73.08       Hithadhoo       300.22        77           6
# 4     39.31     -74.98  Port Elizabeth       290.46        59           1
#
#    Wind Speeds
# 0         3.10
# 1         4.10
# 2         0.05
# 3         4.80
# 4         3.52

# %%
cities_df.set_index('City', inplace=True)
cities_df.head()
# Out:
#                 Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# City
# Castro            -42.48     -73.76       284.15        62           0
# Kitimat            54.02    -128.69       279.15        93          90
# Vaini              15.34      74.49       293.27        97          99
# Hithadhoo          -0.60      73.08       300.22        77           6
# Port Elizabeth     39.31     -74.98       290.46        59           1
#
#                 Wind Speeds
# City
# Castro                 3.10
# Kitimat                4.10
# Vaini                  0.05
# Hithadhoo              4.80
# Port Elizabeth         3.52

# %%
html_table = cities_df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Temperature</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Wind Speeds</th>\n    </tr>\n    <tr>\n      <th>City</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>Castro</th>\n      <td>-42.48</td>\n      <td>-73.76</td>\n      <td>284.15</td>\n      <td>62</td>\n      <td>0</td>\n      <td>3.10</td>\n    </tr>\n    <tr>\n      <th>Kitimat</th>\n      <td>54.02</td>\n      <td>-128.69</td>\n      <td>279.15</td>\n      <td>93</td>\n      <td>90</td>\n      <td>4.10</td>\n    </tr>\n    <tr>\n      <th>Vaini</th>\n      <td>15.34</td>\n      <td>74.49</td>\n      <td>293.27</td>\n      <td>97</td>\n      <td>99</td>\n      <td>0.05</td>\n    </tr>\n    <tr>\n      <th>Hithadhoo</th>\n      <t
# ...

# %%
html_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>Latitude</th>      <th>Longitude</th>      <th>Temperature</th>      <th>Humidity</th>      <th>Cloudiness</th>      <th>Wind Speeds</th>    </tr>    <tr>      <th>City</th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>    </tr>  </thead>  <tbody>    <tr>      <th>Castro</th>      <td>-42.48</td>      <td>-73.76</td>      <td>284.15</td>      <td>62</td>      <td>0</td>      <td>3.10</td>    </tr>    <tr>      <th>Kitimat</th>      <td>54.02</td>      <td>-128.69</td>      <td>279.15</td>      <td>93</td>      <td>90</td>      <td>4.10</td>    </tr>    <tr>      <th>Vaini</th>      <td>15.34</td>      <td>74.49</td>      <td>293.27</td>      <td>97</td>      <td>99</td>      <td>0.05</td>    </tr>    <tr>      <th>Hithadhoo</th>      <td>-0.60</td>      <td>73.08</td>      <td>300.22</td>      <td>77</td>      <td>6</td>      <td>4.80</
# ...

# %%
cities_df.to_html('Data.html')
